# %%
import requests, json
import pandas as pd
import datetime as DT
today = DT.date.today()
day = str(today)
week_ago = today - DT.timedelta(days=7)
week = str(week_ago)
#서울당근(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=232&p_kindcode=01&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#서울무(01,02,03,06)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=01&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_02 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=02&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=03&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_06 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=06&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#서울배(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=400&p_itemcode=412&p_kindcode=01&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#서울배추(01,02,03,06)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=01&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_02 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=02&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=03&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_06 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=06&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#서울상추(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=214&p_kindcode=01&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#서울수박(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=221&p_kindcode=00&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#서울시금치(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=213&p_kindcode=00&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#서울양배추(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=212&p_kindcode=00&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#서울오이(03)
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=223&p_kindcode=03&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#서울토마토(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=225&p_kindcode=00&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#서울풋고추(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=242&p_kindcode=00&p_productrankcode=04&p_countrycode=1101&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#----------------------------구분선----------------------------------------

# %%
#부산당근(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=232&p_kindcode=01&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#부산무(01,02,03,06)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=01&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_02 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=02&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=03&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_06 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=06&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#부산배(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=400&p_itemcode=412&p_kindcode=01&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#부산배추(01,02,03,06)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=01&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_02 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=02&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=03&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_06 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=06&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#부산상추(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=214&p_kindcode=01&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#부산수박(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=221&p_kindcode=00&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#부산시금치(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=213&p_kindcode=00&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#부산양배추(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=212&p_kindcode=00&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#부산오이(03)대구, 부산은 오이가 없음
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=223&p_kindcode=03&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#부산토마토(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=225&p_kindcode=00&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#부산풋고추(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=242&p_kindcode=00&p_productrankcode=04&p_countrycode=2100&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#----------------------------구분선----------------------------------------

# %%
#대구당근(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=232&p_kindcode=01&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#대구무(01,02,03,06)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=01&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_02 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=02&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=03&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_06 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=06&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#대구배(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=400&p_itemcode=412&p_kindcode=01&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#대구배추(01,02,03,06)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=01&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_02 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=02&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=03&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_06 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=06&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#대구상추(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=214&p_kindcode=01&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#대구수박(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=221&p_kindcode=00&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#대구시금치(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=213&p_kindcode=00&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#대구양배추(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=212&p_kindcode=00&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#대구오이(03)대구, 부산은 오이가 없음
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=223&p_kindcode=03&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#대구토마토(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=225&p_kindcode=00&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#대구풋고추(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=242&p_kindcode=00&p_productrankcode=04&p_countrycode=2200&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#----------------------------구분선----------------------------------------

# %%
#광주당근(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=232&p_kindcode=01&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#광주무(01,02,03,06)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=01&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_02 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=02&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=03&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_06 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=06&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#광주배(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=400&p_itemcode=412&p_kindcode=01&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#광주배추(01,02,03,06)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=01&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_02 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=02&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=03&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_06 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=06&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#광주상추(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=214&p_kindcode=01&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#광주수박(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=221&p_kindcode=00&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#광주시금치(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=213&p_kindcode=00&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#광주양배추(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=212&p_kindcode=00&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#광주오이(03)
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=223&p_kindcode=03&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#광주토마토(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=225&p_kindcode=00&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#광주풋고추(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=242&p_kindcode=00&p_productrankcode=04&p_countrycode=2401&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#----------------------------구분선----------------------------------------

# %%
#대전당근(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=232&p_kindcode=01&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#대전무(01,02,03,06)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=01&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_02 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=02&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=03&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_06 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=231&p_kindcode=06&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#대전배(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=400&p_itemcode=412&p_kindcode=01&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#대전배추(01,02,03,06)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=01&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_02 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=02&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=03&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"
url_06 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=211&p_kindcode=06&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#대전상추(01)
url_01 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=214&p_kindcode=01&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_01)
data = response.json()
data

# %%
#대전수박(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=221&p_kindcode=00&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#대전시금치(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=213&p_kindcode=00&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#대전양배추(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=212&p_kindcode=00&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#대전오이(03)
url_03 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=223&p_kindcode=03&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_03)
data = response.json()
data

# %%
#대전토마토(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=225&p_kindcode=00&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data

# %%
#대전풋고추(00)
url_00 = f"http://www.kamis.or.kr/service/price/xml.do?action=periodProductList&p_startday={week}&p_endday={day}&p_itemcategorycode=200&p_itemcode=242&p_kindcode=00&p_productrankcode=04&p_countrycode=2501&p_convert_kg_yn=N&p_cert_key=55809923-b691-4da7-89ea-68e0b445bb26&p_cert_id=3038&p_returntype=json"

response = requests.post(url_00)
data = response.json()
data
