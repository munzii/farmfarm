# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("se_당근.csv",encoding='cp949')

# %%
df.columns
# Out:
# Index(['ds', 'y', '수확시기'], dtype='object')

# %%
df = df.drop(columns=['지점명', '평균기온(°C)', '일강수량(mm)', '평균 풍속(m/s)', '평균 상대습도(%)',
       '합계 일조시간(hr)', '합계 일사량(MJ/m2)', '일 최심적설(cm)', '달러', '엔', '유로', 'GDP',
       '지니계수', '소비자물가상승률', 'M2', '상품수출', '상품수입', '감자류', '채소', '과실', '소비자심리지수',
       '휘발유(92RON)', '경유(0.001%)', '변환', '사과', '배', '복숭아', '포도', '감', '귤',
       '오렌지', '참외', '수박', '딸기', '배추', '상추', '시금치', '양배추', '미나리', '깻잎', '무',
       '열무', '당근', '감자', '고구마', '버섯', '오이', '풋고추', '호박', '가지', '토마토', '파',
       '양파', '마늘', '참깨', '생강', '당근:면적 (ha)', '당근 생산량 (톤)', '전국 당근 면적 (ha)',
       '전국 당근 생산량 (톤)',])

# %%
df
# Out:
#               일시     당근가격  수확시기   p365
# 0     2013-01-01  61000.0   NaN    NaN
# 1     2013-01-02  61000.0   NaN    NaN
# 2     2013-01-03  61000.0   NaN    NaN
# 3     2013-01-04  62330.0   NaN    NaN
# 4     2013-01-05  62330.0   NaN    NaN
# ...          ...      ...   ...    ...
# 3282  2021-12-27  25610.0   1.0  361.0
# 3283  2021-12-28  25730.0   1.0  362.0
# 3284  2021-12-29  25840.0   1.0  363.0
# 3285  2021-12-30  25880.0   1.0  364.0
# 3286  2021-12-31  25870.0   1.0  365.0
#
# [3287 rows x 4 columns]

# %%
df = df[1826:].copy().reset_index(drop=True)
df['일시'] = pd.to_datetime(df['일시'])
df.rename(columns={'일시':'ds','당근가격':'y'},inplace=True)
#df.to_csv('se_당근.csv',encoding='cp949',index=False)

# %%
df
# Out:
#              ds        y  수확시기   p365
# 0    2018-01-01  19670.0   0.0    1.0
# 1    2018-01-02  19670.0   0.0    2.0
# 2    2018-01-03  19170.0   0.0    3.0
# 3    2018-01-04  19110.0   0.0    4.0
# 4    2018-01-05  19080.0   0.0    5.0
# ...         ...      ...   ...    ...
# 1456 2021-12-27  25610.0   1.0  361.0
# 1457 2021-12-28  25730.0   1.0  362.0
# 1458 2021-12-29  25840.0   1.0  363.0
# 1459 2021-12-30  25880.0   1.0  364.0
# 1460 2021-12-31  25870.0   1.0  365.0
#
# [1461 rows x 4 columns]

# %%
df[300:]
# Out:
#               ds        y
# 300   2018-10-28  45200.0
# 301   2018-10-29  45110.0
# 302   2018-10-30  45110.0
# 303   2018-10-31  45110.0
# 304   2018-11-01  44890.0
# ...          ...      ...
# 1456  2021-12-27  25610.0
# 1457  2021-12-28  25730.0
# 1458  2021-12-29  25840.0
# 1459  2021-12-30  25880.0
# 1460  2021-12-31  25870.0
#
# [1161 rows x 2 columns]

# %%
df = pd.read_csv("se_배추.csv",encoding='cp949')

# %%
df = df.fillna(0)

# %%
df['명절'] = df1['명절'].copy()
df['김장철'] = df1['김장철'].copy()

# %%
df['일시'] = pd.to_datetime(df['일시'])
df['year'] = df['일시'].dt.year
df['month'] = df['일시'].dt.month
df['day'] = df['일시'].dt.day

# %%
df.drop(columns=['일시'],inplace=True)

# %%
df
# Out:
#          당근가격  수확시기   p365  year  month  day
# 0     61000.0   NaN    NaN  2013      1    1
# 1     61000.0   NaN    NaN  2013      1    2
# 2     61000.0   NaN    NaN  2013      1    3
# 3     62330.0   NaN    NaN  2013      1    4
# 4     62330.0   NaN    NaN  2013      1    5
# ...       ...   ...    ...   ...    ...  ...
# 3282  25610.0   1.0  361.0  2021     12   27
# 3283  25730.0   1.0  362.0  2021     12   28
# 3284  25840.0   1.0  363.0  2021     12   29
# 3285  25880.0   1.0  364.0  2021     12   30
# 3286  25870.0   1.0  365.0  2021     12   31
#
# [3287 rows x 6 columns]

# %%
plt.figure(figsize=(12,8))

plt.plot(df2['당근가격'][731:1095].reset_index(drop=True), label='2020')
plt.plot(df2['당근가격'][1096:].reset_index(drop=True), label='2021')
plt.legend()
plt.show()

# %%
#plt.figure(figsize=(20,10))
plt.plot(df2['당근가격'][:365], label='2018')
plt.plot(df2['당근가격'][366:730].reset_index(drop=True), label='2019')
plt.legend()
plt.show()

# %%
plt.plot(df2['무가격'])
plt.show()

# %%
plt.plot(df2['배가격'])
plt.show()

# %%
plt.plot(df2['배추가격'])
plt.show()

# %%
#df2 = df1.loc[df1['year']!=2013]
df2 = df.copy()

# %%
df2['365d'] = df2['당근가격'].shift(365)

# %%
df2 = df2.dropna()

# %%
df2.dtypes
# Out:
# 당근가격     float64
# 수확시기     float64
# p365     float64
# year       int64
# month      int64
# day        int64
# 365d     float64
# dtype: object

# %%
df2 = df2[365:].reset_index(drop=True).copy()

# %%
df2
# Out:
#          당근가격  수확시기   p365  year  month  day     365d
# 0     19670.0   0.0    1.0  2018      1    1  60465.0
# 1     19670.0   0.0    2.0  2018      1    2  61000.0
# 2     19170.0   0.0    3.0  2018      1    3  60330.0
# 3     19110.0   0.0    4.0  2018      1    4  60110.0
# 4     19080.0   0.0    5.0  2018      1    5  60000.0
# ...       ...   ...    ...   ...    ...  ...      ...
# 1456  25610.0   1.0  361.0  2021     12   27  21670.0
# 1457  25730.0   1.0  362.0  2021     12   28  21670.0
# 1458  25840.0   1.0  363.0  2021     12   29  21670.0
# 1459  25880.0   1.0  364.0  2021     12   30  21670.0
# 1460  25870.0   1.0  365.0  2021     12   31  22730.0
#
# [1461 rows x 7 columns]

# %%
df2.corr()['배추가격']
# Out:
# 배추가격     1.000000
# 수확시기    -0.043700
# 명절       0.043270
# 김장철     -0.042952
# year     0.702333
# month    0.121019
# day      0.005572
# 365d     0.560837
# Name: 배추가격, dtype: float64

# %%
df2.to_csv("se_당근_ML.csv", encoding='cp949', index=False)

# %%
df = pd.read_csv('se_당근14~20_pattern.csv',encoding='cp949')

# %%
df = pd.read_csv("se_당근.csv",encoding='cp949')

# %%
df = df.drop(columns='김장철')

# %%
y14 = df.loc[df['year']==2014]
y15 = df.loc[df['year']==2015]
y16 = df.loc[df['year']==2016]
y17 = df.loc[df['year']==2017]
y18 = df.loc[df['year']==2018]
y19 = df.loc[df['year']==2019]
y20 = df.loc[df['year']==2020]
y21 = df.loc[df['year']==2021]

# %%
df_1 = pd.concat([y17,y18])
df_1 = pd.concat([df_1,y19])
df_1 = pd.concat([df_1,y20])

# %%
df_1 = pd.concat([y18,y19])
df_1 = pd.concat([df_1,y20])

# %%
df_1['7d'] = df_1['당근가격'].shift(7)

# %%
df_1['1d'] = df_1['당근가격'].shift(1)

# %%
df_1 = df_1[365:]

# %%
df_1
# Out:
#          당근가격  수확시기  명절  year  month  day     365d  patern
# 1461  19670.0     0   0  2018      1    1  60465.0       1
# 1462  19670.0     0   0  2018      1    2  61000.0       2
# 1463  19170.0     0   0  2018      1    3  60330.0       3
# 1464  19110.0     0   0  2018      1    4  60110.0       4
# 1465  19080.0     0   0  2018      1    5  60000.0       5
# ...       ...   ...  ..   ...    ...  ...      ...     ...
# 2552  21670.0     0   0  2020     12   27  31170.0     362
# 2553  21670.0     0   0  2020     12   28  31170.0     363
# 2554  21670.0     0   0  2020     12   29  31200.0     364
# 2555  21670.0     0   0  2020     12   30  31270.0     365
# 2556  22730.0     0   0  2020     12   31  31300.0     366
#
# [1096 rows x 8 columns]

# %%
df_1.to_csv('se_당근18~20_pattern.csv',encoding='cp949',index=False)

# %%
df_1.to_csv('se_당근1d.csv',encoding='cp949',index=False)

# %%
plt.plot(y14['당근가격'])
plt.show()

# %%
plt.plot(y15['당근가격'])
plt.show()

# %%
plt.plot(y16['당근가격'])
plt.show()

# %%
plt.plot(y17['당근가격'])
plt.show()

# %%
plt.plot(y18['당근가격'])
plt.show()

# %%
plt.plot(y19['당근가격'])
plt.show()

# %%
plt.plot(y20['당근가격'])
plt.show()

# %%
plt.plot(y21['당근가격'])
plt.show()

# %%
plt.plot(df22['서울\n단위 (원)'])
plt.show()

# %%
df22 = pd.read_csv("22년서울당근.csv",encoding='cp949')
